# %%
import requests

requests.get("http://localhost:8080/api/state").json()
# Out:
# {'bag_count': 123,
#  'connected': True,
#  'done': False,
#  'grid': [[None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   [None,
#    None,
#    None,
#    None,
# ...

# %%
requests.post("http://localhost:8080/api/place", json={
    "letter": "A",
    "row": 10,
    "col": 11
}).json()

requests.post("http://localhost:8080/api/remove", json={
    "row": 10,
    "col": 7
}).json()

requests.post("http://localhost:8080/api/dump", json={
    "letter": "A"
}).json()
# Out:
# {'message': "'A' not in hand.",
#  'state': {'bag_count': 121,
#   'connected': False,
#   'done': False,
#   'grid': [[None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None],
#    [None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None],
#    [None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None],
#    [None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
#     None,
# ...

# %%
requests.post("http://localhost:8080/api/reset", json={}).json()
# Out:
# {'bag_count': 123,
#  'connected': True,
#  'done': False,
#  'grid': [[None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   [None,
#    None,
#    None,
#    None,
# ...
